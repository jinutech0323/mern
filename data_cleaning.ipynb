# %% [markdown]
# <a href="https://colab.research.google.com/github/jinutech0323/mern/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_excel('customer.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3388733349.py in <cell line: 0>()
# ----> 1 data=pd.read_excel('customer.xlsx')
#
# NameError: name 'pd' is not defined

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-4791e874-8e51-4b7d-87f7-22052931cb8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4791e874-8e51-4b7d-87f7-22052931cb8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     9 non-null      float64
#  2   City    11 non-null     object
#  3   Marks   10 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 484.0+ bytes

# %%
df.describe()
# Out:
#              Age       Marks
# count   9.000000   10.000000
# mean   30.666667  148.700000
# std    10.099505  264.847986
# min    22.000000   24.000000
# 25%    23.000000   56.000000
# 50%    32.000000   71.500000
# 75%    33.000000   88.500000
# max    54.000000  900.000000

# %%
df.isnull().sum()
# Out:
# Name     1
# Age      2
# City     0
# Marks    1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna()
# Out:
#        Name   Age      City  Marks
# 1  Krishnan  22.0     tamil   78.0
# 2      arun  23.0      nadu   56.0
# 3   brintha  33.0   chennai   24.0
# 4      velu  23.0      bang   43.0
# 5     vetri  54.0   mysiore   65.0
# 6     vijay  34.0   madurai   87.0
# 8     manoj  32.0  sbcolony   89.0

# %%
df.dropna()
# Out:
#        Name      Age      City    Marks
# 0      Jinu  no data     karum  no data
# 1  Krishnan     22.0     tamil     78.0
# 2      arun     23.0      nadu     56.0
# 3   brintha     33.0   chennai     24.0
# 4      velu     23.0      bang     43.0
# 5     vetri     54.0   mysiore     65.0
# 6     vijay     34.0   madurai     87.0
# 7   no data  no data  sivakasi    900.0
# 8     manoj     32.0  sbcolony     89.0

# %%
df['Age'].fillna(avg, inplace=True)
# Out:
# /tmp/ipython-input-1161467438.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(avg, inplace=True)

# %%
avg=df['Age'].mean()

# %%
df['Marks'].fillna(0,inplace=True)
# Out:
# /tmp/ipython-input-130461783.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(0,inplace=True)

# %%
df
# Out:
#        Name        Age      City  Marks
# 0      Jinu  31.571429     karum    0.0
# 1  Krishnan  22.000000     tamil   78.0
# 2      arun  23.000000      nadu   56.0
# 3   brintha  33.000000   chennai   24.0
# 4      velu  23.000000      bang   43.0
# 5     vetri  54.000000   mysiore   65.0
# 6     vijay  34.000000   madurai   87.0
# 7       NaN  31.571429  sivakasi  900.0
# 8     manoj  32.000000  sbcolony   89.0

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      0
# City     0
# Marks    0
# dtype: int64

# %%
df.fillna("No name", inplace=True)

# %%
df
# Out:
#        Name        Age      City  Marks
# 0      Jinu  31.571429     karum    0.0
# 1  Krishnan  22.000000     tamil   78.0
# 2      arun  23.000000      nadu   56.0
# 3   brintha  33.000000   chennai   24.0
# 4      velu  23.000000      bang   43.0
# 5     vetri  54.000000   mysiore   65.0
# 6     vijay  34.000000   madurai   87.0
# 7   No name  31.571429  sivakasi  900.0
# 8     manoj  32.000000  sbcolony   89.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('output.csv', index=False)

# %%
files.download('output.csv')

# %%
 import matplotlib.pyplot as plt

# %%
plt.scatter(df['City'], df['Marks'], color='red')
plt.title(" City vs Marks")
plt.xlabel("City")
plt.ylabel('Marks')
plt.show()

# %%
plt.bar(df['City'], df['Age'], color='red')
plt.title(" age vs Marks")
plt.xlabel("City")
plt.ylabel('Marks')
plt.show()

# %%
plt.hist(df['Age'], color='red', bins=3)

plt.show()

# %%
plt.plot(df['Name'], df['Age'], color='red')
plt.title(" age vs Marks")
plt.xlabel("City")
plt.ylabel('Marks')
plt.show()

# %%
plt.pie(df['Age'], labels=df['City'])
plt.title(" age vs Marks")
# Out:
# Text(0.5, 1.0, ' age vs Marks')

# %%
plt.figure(figsize=(10,8))
plt.suptitle(" fraud Analysis")
plt.subplot(2,2,1)
plt.bar(df['City'], df['Marks'])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.subplot(2,2,2)
plt.plot(df['City'], df['Marks'])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.subplot(2,2,3)
plt.scatter(df['Age'], df['Marks'])
plt.subplot(2,2,4)
plt.hist(df['Age'], bins=5)
plt.tight_layout()
plt.savefig('dashboard.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4191534334.py in <cell line: 0>()
# ----> 1 plt.figure(figsize=(10,8))
#       2 plt.suptitle(" fraud Analysis")
#       3 plt.subplot(2,2,1)
#       4 plt.bar(df['City'], df['Marks'])
#       5 plt.xticks(rotation=45, ha='right')
#
# NameError: name 'plt' is not defined

# %%
files.download('dashboard.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-726311917.py in <cell line: 0>()
# ----> 1 files.download('dashboard.png')
#
# NameError: name 'files' is not defined

# %%
import pandas as pd
from google.colab import files

# %%
up=files.upload()
# Out:
#      <input type="file" id="files-5a285e59-41bc-4050-8269-148f063c894e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a285e59-41bc-4050-8269-148f063c894e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r'Global_Superstore1.xlsx')

# %%
group=pd.groupby('Region')['Sales'].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-282896830.py in <cell line: 0>()
# ----> 1 group=pd.groupby('Region')['Sales'].sum()
#
# AttributeError: module 'pandas' has no attribute 'groupby'

# %%
pivot=pd.pivot(df,
               values='Sales',
               index='Region')
